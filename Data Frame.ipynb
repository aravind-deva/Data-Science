# %%
import numpy as np
import pandas as pd

df=pd.read_csv("./survey_results_public.csv")

print(f"{len(df)} - rows, {df.shape[1]} - columns")
print(df.shape)
# Out:
# 19102 - rows, 154 - columns
# (19102, 154)

# %% [markdown]
# ### Display options

# %%
import pandas as pd
pd.options.display.max_rows=500
pd.options.display.max_columns=1000

# %%
print("How to find non-null columns")
# Out:
# How to find non-null columns

# %%
print("Drop rows - give row label(s) - axis=0")
df.drop(0,axis=0).head(3)
# Out:
# Drop rows - give row label(s) - axis=0
#    Respondent                                       Professional ProgramHobby  \
# 1           2                                            Student    Yes, both
# 2           3                             Professional developer    Yes, both
# 3           4  Professional non-developer who sometimes write...    Yes, both
#
#           Country      University    EmploymentStatus  \
# 1  United Kingdom  Yes, full-time  Employed part-time
# 2  United Kingdom              No  Employed full-time
# 3   United States              No  Employed full-time
#
#                                      FormalEducation  \
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
#
#                                   MajorUndergrad  \
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
#
#                                           HomeRemote  \
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 1        20 to 99 employees  ...      Strongly disagree   Male
# 2  10,000 or more employees  ...               Disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
#
#   HighestEducationParents                          Race      SurveyLong  \
# 1       A master's degree  White or of European descent  Somewhat agree
# 2   A professional degree  White or of European descent  Somewhat agree
# 3       A doctoral degree  White or of European descent           Agree
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
#
#    ExpectedSalary
# 1         37500.0
# 2             NaN
# 3             NaN
#
# [3 rows x 154 columns]

# %%
df.drop([1,2],axis=0).head(3)
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby        Country University  \
# 0                  Yes, both  United States         No
# 3                  Yes, both  United States         No
# 4  Yes, I program as a hobby    Switzerland         No
#
#                          EmploymentStatus   FormalEducation  \
# 0  Not employed, and not looking for work  Secondary school
# 3                      Employed full-time   Doctoral degree
# 4                      Employed full-time   Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 0                       NaN  ...      Strongly disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
# 4        10 to 19 employees  ...                    NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers  Salary  \
# 0       Strongly agree           Disagree    Strongly agree     NaN
# 3                Agree     Somewhat agree    Strongly agree     NaN
# 4                  NaN                NaN               NaN     NaN
#
#    ExpectedSalary
# 0             NaN
# 3             NaN
# 4             NaN
#
# [3 rows x 154 columns]

# %%
print("Drop Columns- give column label(s),axis=1")
df.drop(['Respondent','Professional'],axis=1).head(2)
# Out:
# Drop Columns- give column label(s),axis=1
#   ProgramHobby         Country      University  \
# 0    Yes, both   United States              No
# 1    Yes, both  United Kingdom  Yes, full-time
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
#
#                              MajorUndergrad  \
# 0                                       NaN
# 1  Computer science or software engineering
#
#                               HomeRemote         CompanySize  \
# 0                                    NaN                 NaN
# 1  More than half, but not all, the time  20 to 99 employees
#
#                                          CompanyType   YearsProgram  ...  \
# 0                                                NaN   2 to 3 years  ...
# 1  Privately-held limited company, not in startup...  9 to 10 years  ...
#
#   StackOverflowMakeMoney Gender HighestEducationParents  \
# 0      Strongly disagree   Male             High school
# 1      Strongly disagree   Male       A master's degree
#
#                            Race         SurveyLong QuestionsInteresting  \
# 0  White or of European descent  Strongly disagree       Strongly agree
# 1  White or of European descent     Somewhat agree       Somewhat agree
#
#    QuestionsConfusing  InterestedAnswers Salary ExpectedSalary
# 0            Disagree     Strongly agree    NaN            NaN
# 1            Disagree     Strongly agree    NaN        37500.0
#
# [2 rows x 152 columns]

# %%
print("simple technique. axis=0 means columns remain same, rows get reduced(either mean/sum or rows get deleted in case of dropna")
print("simple technique. axis=1 means rows remain same, columns get reduced(either mean/sum or columns get deleted in case of dropna")

print("Drop na rows with any NaN column ,axis=0 => traverse downward and then traverse side ward - rowwise")
print("Drop na rows with specified NaN column ,axis=0 => traverse downward, if you find NaN,drop that row  ")
df.dropna(axis=0).shape
# Out:
# simple technique. axis=0 means columns remain same, rows get reduced(either mean/sum or rows get deleted in case of dropna
# simple technique. axis=1 means rows remain same, columns get reduced(either mean/sum or columns get deleted in case of dropna
# Drop na rows with any NaN column ,axis=0 => traverse downward and then traverse side ward - rowwise
# Drop na rows with specified NaN column ,axis=0 => traverse downward, if you find NaN,drop that row
# (0, 154)

# %%
print("Drop na rows with specified NaN column ,axis=0 => traverse downward and then traverse side ward - rowwise")
print("Drop na rows with specified NaN column ,axis=0 => traverse downward, if you find NaN,drop that row  ")
print("Drops only rows where Salary column in null")

df.dropna(axis=0,subset=['Salary']).shape
# Out:
# Drop na rows with specified NaN column ,axis=0 => traverse downward and then traverse side ward - rowwise
# Drop na rows with specified NaN column ,axis=0 => traverse downward, if you find NaN,drop that row
# Drops only rows where Salary column in null
# (5009, 154)

# %%
print("Drop na columns , axis=1 , traverse side wards and then traverse downward")
print("Prints all non-non columns")
df.dropna(axis=1).info()
# Out:
# Drop na columns , axis=1 , traverse side wards and then traverse downward
# Prints all non-non columns
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19102 entries, 0 to 19101
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Respondent        19102 non-null  int64
#  1   Professional      19102 non-null  object
#  2   ProgramHobby      19102 non-null  object
#  3   Country           19102 non-null  object
#  4   University        19102 non-null  object
#  5   EmploymentStatus  19102 non-null  object
#  6   FormalEducation   19102 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %%
print("Drops all NaN columns")
df.dropna(axis=1).columns
# Out:
# Drops all NaN columns
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation'],
#       dtype='object')

# %%
print("you cannot drop a specific NaN column. only all NaN columns")
df.dropna(subset=['Salary'],axis=1)
# Out:
# you cannot drop a specific NaN column. only all NaN columns
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8ad562c61e12> in <module>
#       1 print("you cannot drop a specific NaN column. only all NaN columns")
# ----> 2 df.dropna(subset=['Salary'],axis=1)
#
# ~\miniconda3\envs\deep-learning\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5157             check = indices == -1
#    5158             if check.any():
# -> 5159                 raise KeyError(list(np.compress(check, subset)))
#    5160             agg_obj = self.take(indices, axis=agg_axis)
#    5161
#
# KeyError: ['Salary']

# %%
df.dropna(how="any",axis=1).columns
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation'],
#       dtype='object')

# %%
df.dropna(how="all",axis=1).columns ## Columns with All NaN values
# Out:
# Index(['Respondent', 'Professional', 'ProgramHobby', 'Country', 'University',
#        'EmploymentStatus', 'FormalEducation', 'MajorUndergrad', 'HomeRemote',
#        'CompanySize',
#        ...
#        'StackOverflowMakeMoney', 'Gender', 'HighestEducationParents', 'Race',
#        'SurveyLong', 'QuestionsInteresting', 'QuestionsConfusing',
#        'InterestedAnswers', 'Salary', 'ExpectedSalary'],
#       dtype='object', length=154)

# %%
# Drop any column if row labels 0,1,2 have NaN in that column
df.dropna(subset=[0,1,2],axis=1).shape
# Out:
# (19102, 49)

# %%
df.dropna(axis=1).shape
# Out:
# (19102, 7)

# %%
#default how =any
df.dropna(how="all",axis=1).shape
# Out:
# (19102, 154)

# %%
print('df.index or df.columns is an Object.Multi level index/columns have complex representation')
print()
print('Use df.index.tolist() or use df.columns.tolist() or df.index[boolean array].tolist() to retrieve subset')
print('df.values or df.index.values or df.columns.values given numpy arrays')
type(df.index.tolist()) ,type(df.index.values),type(df.values),type(df.columns.values),\
type(df.index.values.tolist())
# Out:
# df.index or df.columns is an Object.Multi level index/columns have complex representation
#
# Use df.index.tolist() or use df.columns.tolist() or df.index[boolean array].tolist() to retrieve subset
# df.values or df.index.values or df.columns.values given numpy arrays
# (list, numpy.ndarray, numpy.ndarray, numpy.ndarray, list)

# %%
print("selecting specific rows/cols can be using boolean array")


bool_cols=np.random.randint(2,size=(len(df.columns.tolist()))) == 1
print(bool_cols)
df.iloc[:,bool_cols]
# Out:
# selecting specific rows/cols can be using boolean array
# [ True False  True False False  True False False  True  True  True False
#   True False False  True False  True False False  True  True  True False
#   True False  True  True False False False False False False False False
#   True  True  True False False  True  True  True  True False False False
#   True  True False  True False  True  True False  True  True False  True
#  False  True False  True  True  True  True False False  True False False
#   True  True False  True False False  True False  True  True  True  True
#   True  True  True False False  True False False  True False False False
#   True False False False  True False  True  True False  True False False
#   True  True  True  True  True  True False  True  True False False  True
#   True False  True  True  True False  True  True False False False  True
#   True False False False False False  True False False  True False False
#   True False False False  True False False  True False  True]
#        Respondent               ProgramHobby  \
# 0               1                  Yes, both
# 1               2                  Yes, both
# 2               3                  Yes, both
# 3               4                  Yes, both
# 4               5  Yes, I program as a hobby
# ...           ...                        ...
# 19097       19098  Yes, I program as a hobby
# 19098       19099  Yes, I program as a hobby
# 19099       19100  Yes, I program as a hobby
# 19100       19101  Yes, I program as a hobby
# 19101       19102  Yes, I program as a hobby
#
#                                         EmploymentStatus  \
# 0                 Not employed, and not looking for work
# 1                                     Employed part-time
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 19097                                 Employed full-time
# 19098             Not employed, and not looking for work
# 19099  Independent contractor, freelancer, or self-em...
# 19100                                 Employed full-time
# 19101                                 Employed full-time
#
#                                               HomeRemote  \
# 0                                                    NaN
# 1                  More than half, but not all, the time
# 2      Less than half the time, but at least one day ...
# 3      Less than half the time, but at least one day ...
# 4                                                  Never
# ...                                                  ...
# 19097                              A few days each month
# 19098                                                NaN
# 19099                                              Never
# 19100  Less than half the time, but at least one day ...
# 19101  All or almost all the time (I'm full-time remote)
#
#                     CompanySize  \
# 0                           NaN
# 1            20 to 99 employees
# 2      10,000 or more employees
# 3      10,000 or more employees
# 4            10 to 19 employees
# ...                         ...
# 19097        10 to 19 employees
# 19098                       NaN
# 19099                       NaN
# 19100      100 to 499 employees
# 19101      100 to 499 employees
#
#                                              CompanyType     YearsCodedJob  \
# 0                                                    NaN               NaN
# 1      Privately-held limited company, not in startup...               NaN
# 2                            Publicly-traded corporation  20 or more years
# 3      Non-profit/non-governmental organization or pr...     9 to 10 years
# 4      Privately-held limited company, not in startup...    10 to 11 years
# ...                                                  ...               ...
# 19097  Privately-held limited company, not in startup...      1 to 2 years
# 19098                                                NaN               NaN
# 19099                                                NaN    14 to 15 years
# 19100  Sole proprietorship or partnership, not in sta...  20 or more years
# 19101  Sole proprietorship or partnership, not in sta...     9 to 10 years
#
#                WebDeveloperType       NonDeveloperType ExCoderReturn  ...  \
# 0                           NaN                    NaN           NaN  ...
# 1                           NaN                    NaN           NaN  ...
# 2                           NaN                    NaN           NaN  ...
# 3                           NaN         Data scientist           NaN  ...
# 4                           NaN                    NaN           NaN  ...
# ...                         ...                    ...           ...  ...
# 19097  Full stack Web developer                    NaN           NaN  ...
# 19098                       NaN                    NaN           NaN  ...
# 19099                       NaN  Analyst or consultant           NaN  ...
# 19100                       NaN                    NaN           NaN  ...
# 19101                       NaN                    NaN           NaN  ...
#
#                                   StackOverflowDescribes  \
# 0      I have created a CV or Developer Story on Stac...
# 1      I have created a CV or Developer Story on Stac...
# 2      I have created a CV or Developer Story on Stac...
# 3      I have created a CV or Developer Story on Stac...
# 4                                                    NaN
# ...                                                  ...
# 19097  I've visited Stack Overflow, but haven't logge...
# 19098                                                NaN
# 19099                                                NaN
# 19100  I have a login for Stack Overflow, but haven't...
# 19101                                                NaN
#
#       StackOverflowSatisfaction  StackOverflowJobListing  \
# 0                           9.0            Once or twice
# 1                           8.0            Once or twice
# 2                           8.0      Haven't done at all
# 3                          10.0  At least once each week
# 4                           NaN                      NaN
# ...                         ...                      ...
# 19097                       8.0      Haven't done at all
# 19098                       NaN                      NaN
# 19099                       NaN                      NaN
# 19100                       9.0      Haven't done at all
# 19101                       NaN                      NaN
#
#       StackOverflowCompanyPage StackOverflowAdsDistracting  \
# 0          Haven't done at all           Strongly disagree
# 1                Once or twice           Strongly disagree
# 2          Haven't done at all                    Disagree
# 3                Several times           Strongly disagree
# 4                          NaN                         NaN
# ...                        ...                         ...
# 19097      Haven't done at all                    Disagree
# 19098                      NaN                         NaN
# 19099                      NaN                         NaN
# 19100      Haven't done at all                    Disagree
# 19101                      NaN                         NaN
#
#       StackOverflowHelpful StackOverflowMakeMoney         SurveyLong  \
# 0                    Agree      Strongly disagree  Strongly disagree
# 1                    Agree      Strongly disagree     Somewhat agree
# 2                    Agree               Disagree     Somewhat agree
# 3           Strongly agree               Disagree              Agree
# 4                      NaN                    NaN                NaN
# ...                    ...                    ...                ...
# 19097                Agree               Disagree     Somewhat agree
# 19098                  NaN                    NaN                NaN
# 19099                  NaN                    NaN                NaN
# 19100                Agree               Disagree     Somewhat agree
# 19101                  NaN                    NaN                NaN
#
#       InterestedAnswers ExpectedSalary
# 0        Strongly agree            NaN
# 1        Strongly agree        37500.0
# 2                 Agree            NaN
# 3        Strongly agree            NaN
# 4                   NaN            NaN
# ...                 ...            ...
# 19097             Agree            NaN
# 19098               NaN            NaN
# 19099               NaN            NaN
# 19100             Agree            NaN
# 19101               NaN            NaN
#
# [19102 rows x 77 columns]

# %% [markdown]
# ### Find duplicated rows vs drop_duplicates

# %%
from sklearn.datasets import load_iris
iris=load_iris()
dup_df=pd.DataFrame(iris.data)

# %%
dup_df[ dup_df.duplicated() ] ## column name is 0
# Out:
#        0    1    2    3
# 142  5.8  2.7  5.1  1.9

# %%
dup_df[ dup_df.duplicated(0) ]
# Out:
#        0    1    2    3
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 12   4.8  3.0  1.4  0.1
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# 28   5.2  3.4  1.4  0.2
# 29   4.7  3.2  1.6  0.2
# 30   4.8  3.1  1.6  0.2
# 31   5.4  3.4  1.5  0.4
# 32   5.2  4.1  1.5  0.1
# 34   4.9  3.1  1.5  0.2
# 35   5.0  3.2  1.2  0.2
# 36   5.5  3.5  1.3  0.2
# 37   4.9  3.6  1.4  0.1
# 38   4.4  3.0  1.3  0.2
# 39   5.1  3.4  1.5  0.2
# 40   5.0  3.5  1.3  0.3
# 42   4.4  3.2  1.3  0.2
# 43   5.0  3.5  1.6  0.6
# 44   5.1  3.8  1.9  0.4
# 45   4.8  3.0  1.4  0.3
# 46   5.1  3.8  1.6  0.2
# 47   4.6  3.2  1.4  0.2
# 49   5.0  3.3  1.4  0.2
# 53   5.5  2.3  4.0  1.3
# 55   5.7  2.8  4.5  1.3
# 57   4.9  2.4  3.3  1.0
# 59   5.2  2.7  3.9  1.4
# 60   5.0  2.0  3.5  1.0
# 66   5.6  3.0  4.5  1.5
# 67   5.8  2.7  4.1  1.0
# 69   5.6  2.5  3.9  1.1
# 70   5.9  3.2  4.8  1.8
# 71   6.1  2.8  4.0  1.3
# 72   6.3  2.5  4.9  1.5
# 73   6.1  2.8  4.7  1.2
# 74   6.4  2.9  4.3  1.3
# 75   6.6  3.0  4.4  1.4
# 77   6.7  3.0  5.0  1.7
# 78   6.0  2.9  4.5  1.5
# 79   5.7  2.6  3.5  1.0
# 80   5.5  2.4  3.8  1.1
# 81   5.5  2.4  3.7  1.0
# 82   5.8  2.7  3.9  1.2
# 83   6.0  2.7  5.1  1.6
# 84   5.4  3.0  4.5  1.5
# 85   6.0  3.4  4.5  1.6
# 86   6.7  3.1  4.7  1.5
# 87   6.3  2.3  4.4  1.3
# 88   5.6  3.0  4.1  1.3
# 89   5.5  2.5  4.0  1.3
# 90   5.5  2.6  4.4  1.2
# 91   6.1  3.0  4.6  1.4
# 92   5.8  2.6  4.0  1.2
# 93   5.0  2.3  3.3  1.0
# 94   5.6  2.7  4.2  1.3
# 95   5.7  3.0  4.2  1.2
# 96   5.7  2.9  4.2  1.3
# 97   6.2  2.9  4.3  1.3
# 98   5.1  2.5  3.0  1.1
# 99   5.7  2.8  4.1  1.3
# 100  6.3  3.3  6.0  2.5
# 101  5.8  2.7  5.1  1.9
# 103  6.3  2.9  5.6  1.8
# 104  6.5  3.0  5.8  2.2
# 106  4.9  2.5  4.5  1.7
# 108  6.7  2.5  5.8  1.8
# 110  6.5  3.2  5.1  2.0
# 111  6.4  2.7  5.3  1.9
# 112  6.8  3.0  5.5  2.1
# 113  5.7  2.5  5.0  2.0
# 114  5.8  2.8  5.1  2.4
# 115  6.4  3.2  5.3  2.3
# 116  6.5  3.0  5.5  1.8
# 118  7.7  2.6  6.9  2.3
# 119  6.0  2.2  5.0  1.5
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# 126  6.2  2.8  4.8  1.8
# 127  6.1  3.0  4.9  1.8
# 128  6.4  2.8  5.6  2.1
# 129  7.2  3.0  5.8  1.6
# 132  6.4  2.8  5.6  2.2
# 133  6.3  2.8  5.1  1.5
# 134  6.1  2.6  5.6  1.4
# 135  7.7  3.0  6.1  2.3
# 136  6.3  3.4  5.6  2.4
# 137  6.4  3.1  5.5  1.8
# 138  6.0  3.0  4.8  1.8
# 139  6.9  3.1  5.4  2.1
# 140  6.7  3.1  5.6  2.4
# 141  6.9  3.1  5.1  2.3
# 142  5.8  2.7  5.1  1.9
# 143  6.8  3.2  5.9  2.3
# 144  6.7  3.3  5.7  2.5
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8

# %%
dup_df[ dup_df.duplicated(0) ][0].value_counts()
# Out:
# 0
# 5.0    9
# 5.1    8
# 6.3    8
# 5.7    7
# 6.7    7
# 6.4    6
# 5.5    6
# 5.8    6
# 4.9    5
# 5.4    5
# 6.0    5
# 5.6    5
# 6.1    5
# 4.8    4
# 6.5    4
# 4.6    3
# 7.7    3
# 6.9    3
# 5.2    3
# 6.2    3
# 6.8    2
# 5.9    2
# 4.4    2
# 7.2    2
# 6.6    1
# 4.7    1
# Name: count, dtype: int64

# %%
dup_df[0].value_counts()
# Out:
# 0
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
dup_df[ dup_df.duplicated(0,keep=False) ]
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1
# 14   5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# 27   5.2  3.5  1.5  0.2
# 28   5.2  3.4  1.4  0.2
# 29   4.7  3.2  1.6  0.2
# 30   4.8  3.1  1.6  0.2
# 31   5.4  3.4  1.5  0.4
# 32   5.2  4.1  1.5  0.1
# 33   5.5  4.2  1.4  0.2
# 34   4.9  3.1  1.5  0.2
# 35   5.0  3.2  1.2  0.2
# 36   5.5  3.5  1.3  0.2
# 37   4.9  3.6  1.4  0.1
# 38   4.4  3.0  1.3  0.2
# 39   5.1  3.4  1.5  0.2
# 40   5.0  3.5  1.3  0.3
# 42   4.4  3.2  1.3  0.2
# 43   5.0  3.5  1.6  0.6
# 44   5.1  3.8  1.9  0.4
# 45   4.8  3.0  1.4  0.3
# 46   5.1  3.8  1.6  0.2
# 47   4.6  3.2  1.4  0.2
# 49   5.0  3.3  1.4  0.2
# 51   6.4  3.2  4.5  1.5
# 52   6.9  3.1  4.9  1.5
# 53   5.5  2.3  4.0  1.3
# 54   6.5  2.8  4.6  1.5
# 55   5.7  2.8  4.5  1.3
# 56   6.3  3.3  4.7  1.6
# 57   4.9  2.4  3.3  1.0
# 58   6.6  2.9  4.6  1.3
# 59   5.2  2.7  3.9  1.4
# 60   5.0  2.0  3.5  1.0
# 61   5.9  3.0  4.2  1.5
# 62   6.0  2.2  4.0  1.0
# 63   6.1  2.9  4.7  1.4
# 64   5.6  2.9  3.6  1.3
# 65   6.7  3.1  4.4  1.4
# 66   5.6  3.0  4.5  1.5
# 67   5.8  2.7  4.1  1.0
# 68   6.2  2.2  4.5  1.5
# 69   5.6  2.5  3.9  1.1
# 70   5.9  3.2  4.8  1.8
# 71   6.1  2.8  4.0  1.3
# 72   6.3  2.5  4.9  1.5
# 73   6.1  2.8  4.7  1.2
# 74   6.4  2.9  4.3  1.3
# 75   6.6  3.0  4.4  1.4
# 76   6.8  2.8  4.8  1.4
# 77   6.7  3.0  5.0  1.7
# 78   6.0  2.9  4.5  1.5
# 79   5.7  2.6  3.5  1.0
# 80   5.5  2.4  3.8  1.1
# 81   5.5  2.4  3.7  1.0
# 82   5.8  2.7  3.9  1.2
# 83   6.0  2.7  5.1  1.6
# 84   5.4  3.0  4.5  1.5
# 85   6.0  3.4  4.5  1.6
# 86   6.7  3.1  4.7  1.5
# 87   6.3  2.3  4.4  1.3
# 88   5.6  3.0  4.1  1.3
# 89   5.5  2.5  4.0  1.3
# 90   5.5  2.6  4.4  1.2
# 91   6.1  3.0  4.6  1.4
# 92   5.8  2.6  4.0  1.2
# 93   5.0  2.3  3.3  1.0
# 94   5.6  2.7  4.2  1.3
# 95   5.7  3.0  4.2  1.2
# 96   5.7  2.9  4.2  1.3
# 97   6.2  2.9  4.3  1.3
# 98   5.1  2.5  3.0  1.1
# 99   5.7  2.8  4.1  1.3
# 100  6.3  3.3  6.0  2.5
# 101  5.8  2.7  5.1  1.9
# 103  6.3  2.9  5.6  1.8
# 104  6.5  3.0  5.8  2.2
# 106  4.9  2.5  4.5  1.7
# 108  6.7  2.5  5.8  1.8
# 109  7.2  3.6  6.1  2.5
# 110  6.5  3.2  5.1  2.0
# 111  6.4  2.7  5.3  1.9
# 112  6.8  3.0  5.5  2.1
# 113  5.7  2.5  5.0  2.0
# 114  5.8  2.8  5.1  2.4
# 115  6.4  3.2  5.3  2.3
# 116  6.5  3.0  5.5  1.8
# 117  7.7  3.8  6.7  2.2
# 118  7.7  2.6  6.9  2.3
# 119  6.0  2.2  5.0  1.5
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# 126  6.2  2.8  4.8  1.8
# 127  6.1  3.0  4.9  1.8
# 128  6.4  2.8  5.6  2.1
# 129  7.2  3.0  5.8  1.6
# 132  6.4  2.8  5.6  2.2
# 133  6.3  2.8  5.1  1.5
# 134  6.1  2.6  5.6  1.4
# 135  7.7  3.0  6.1  2.3
# 136  6.3  3.4  5.6  2.4
# 137  6.4  3.1  5.5  1.8
# 138  6.0  3.0  4.8  1.8
# 139  6.9  3.1  5.4  2.1
# 140  6.7  3.1  5.6  2.4
# 141  6.9  3.1  5.1  2.3
# 142  5.8  2.7  5.1  1.9
# 143  6.8  3.2  5.9  2.3
# 144  6.7  3.3  5.7  2.5
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8

# %%
dup_df[0].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
dup_df[dup_df[0]== 5.8]
# Out:
#        0    1    2    3
# 14   5.8  4.0  1.2  0.2
# 67   5.8  2.7  4.1  1.0
# 82   5.8  2.7  3.9  1.2
# 92   5.8  2.6  4.0  1.2
# 101  5.8  2.7  5.1  1.9
# 114  5.8  2.8  5.1  2.4
# 142  5.8  2.7  5.1  1.9
