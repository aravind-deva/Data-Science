# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.plot(kind='bar')
plt.show()

# %%
df.iloc[0,1]=-1.5

# %%
df.style.bar(subset=[df.columns[1]],align='mid',color=['red', 'green'])
# Out:
# <style  type="text/css" >
# #T_6661a_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 25.4%, transparent 25.4%);
#         }#T_6661a_row1_col1,#T_6661a_row12_col1,#T_6661a_row13_col1,#T_6661a_row25_col1,#T_6661a_row38_col1,#T_6661a_row45_col1,#T_6661a_row61_col1,#T_6661a_row66_col1,#T_6661a_row75_col1,#T_6661a_row77_col1,#T_6661a_row84_col1,#T_6661a_row88_col1,#T_6661a_row91_col1,#T_6661a_row95_col1,#T_6661a_row102_col1,#T_6661a_row104_col1,#T_6661a_row105_col1,#T_6661a_row112_col1,#T_6661a_row116_col1,#T_6661a_row127_col1,#T_6661a_row129_col1,#T_6661a_row135_col1,#T_6661a_row138_col1,#T_6661a_row145_col1,#T_6661a_row147_col1,#T_6661a_row149_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 76.3%, transparent 76.3%);
#         }#T_6661a_row2_col1,#T_6661a_row29_col1,#T_6661a_row35_col1,#T_6661a_row42_col1,#T_6661a_row47_col1,#T_6661a_row50_col1,#T_6661a_row51_col1,#T_6661a_row70_col1,#T_6661a_row110_col1,#T_6661a_row115_col1,#T_6661a_row120_col1,#T_6661a_row125_col1,#T_6661a_row143_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 79.7%, transparent 79.7%);
#         }#T_6661a_row3_col1,#T_6661a_row9_col1,#T_6661a_row30_col1,#T_6661a_row34_col1,#T_6661a_row52_col1,#T_6661a_row65_col1,#T_6661a_row86_col1,#T_6661a_row137_col1,#T_6661a_row139_col1,#T_6661a_row140_col1,#T_6661a_row141_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 78.0%, transparent 78.0%);
#         }#T_6661a_row4_col1,#T_6661a_row22_col1,#T_6661a_row37_col1,#T_6661a_row109_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 86.4%, transparent 86.4%);
#         }#T_6661a_row5_col1,#T_6661a_row16_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 91.5%, transparent 91.5%);
#         }#T_6661a_row6_col1,#T_6661a_row7_col1,#T_6661a_row11_col1,#T_6661a_row20_col1,#T_6661a_row24_col1,#T_6661a_row26_col1,#T_6661a_row28_col1,#T_6661a_row31_col1,#T_6661a_row39_col1,#T_6661a_row85_col1,#T_6661a_row136_col1,#T_6661a_row148_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 83.1%, transparent 83.1%);
#         }#T_6661a_row8_col1,#T_6661a_row58_col1,#T_6661a_row63_col1,#T_6661a_row64_col1,#T_6661a_row74_col1,#T_6661a_row78_col1,#T_6661a_row96_col1,#T_6661a_row97_col1,#T_6661a_row103_col1,#T_6661a_row107_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 74.6%, transparent 74.6%);
#         }#T_6661a_row10_col1,#T_6661a_row21_col1,#T_6661a_row48_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 88.1%, transparent 88.1%);
#         }#T_6661a_row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 93.2%, transparent 93.2%);
#         }#T_6661a_row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 100.0%, transparent 100.0%);
#         }#T_6661a_row17_col1,#T_6661a_row27_col1,#T_6661a_row36_col1,#T_6661a_row40_col1,#T_6661a_row43_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 84.7%, transparent 84.7%);
#         }#T_6661a_row18_col1,#T_6661a_row19_col1,#T_6661a_row44_col1,#T_6661a_row46_col1,#T_6661a_row117_col1,#T_6661a_row131_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 89.8%, transparent 89.8%);
#         }#T_6661a_row23_col1,#T_6661a_row49_col1,#T_6661a_row56_col1,#T_6661a_row100_col1,#T_6661a_row124_col1,#T_6661a_row144_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 81.4%, transparent 81.4%);
#         }#T_6661a_row32_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 94.9%, transparent 94.9%);
#         }#T_6661a_row33_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 96.6%, transparent 96.6%);
#         }#T_6661a_row41_col1,#T_6661a_row53_col1,#T_6661a_row87_col1,#T_6661a_row93_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 64.4%, transparent 64.4%);
#         }#T_6661a_row54_col1,#T_6661a_row55_col1,#T_6661a_row71_col1,#T_6661a_row73_col1,#T_6661a_row76_col1,#T_6661a_row99_col1,#T_6661a_row114_col1,#T_6661a_row121_col1,#T_6661a_row122_col1,#T_6661a_row126_col1,#T_6661a_row128_col1,#T_6661a_row130_col1,#T_6661a_row132_col1,#T_6661a_row133_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 72.9%, transparent 72.9%);
#         }#T_6661a_row57_col1,#T_6661a_row80_col1,#T_6661a_row81_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 66.1%, transparent 66.1%);
#         }#T_6661a_row59_col1,#T_6661a_row67_col1,#T_6661a_row82_col1,#T_6661a_row83_col1,#T_6661a_row94_col1,#T_6661a_row101_col1,#T_6661a_row111_col1,#T_6661a_row123_col1,#T_6661a_row142_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 71.2%, transparent 71.2%);
#         }#T_6661a_row60_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 59.3%, transparent 59.3%);
#         }#T_6661a_row62_col1,#T_6661a_row68_col1,#T_6661a_row119_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 62.7%, transparent 62.7%);
#         }#T_6661a_row69_col1,#T_6661a_row72_col1,#T_6661a_row89_col1,#T_6661a_row98_col1,#T_6661a_row106_col1,#T_6661a_row108_col1,#T_6661a_row113_col1,#T_6661a_row146_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 67.8%, transparent 67.8%);
#         }#T_6661a_row79_col1,#T_6661a_row90_col1,#T_6661a_row92_col1,#T_6661a_row118_col1,#T_6661a_row134_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.4%, green 25.4%, green 69.5%, transparent 69.5%);
#         }</style><table id="T_6661a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length (cm)</th>        <th class="col_heading level0 col1" >sepal width (cm)</th>        <th class="col_heading level0 col2" >petal length (cm)</th>        <th class="col_heading level0 col3" >petal width (cm)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6661a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6661a_row0_col0" class="data row0 col0" >5.100000</td>
#                         <td id="T_6661a_row0_col1" class="data row0 col1" >-1.500000</td>
#                         <td id="T_6661a_row0_col2" class="data row0 col2" >

# %%
df[df.columns[0]].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df[df.columns[1]].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.filter(regex='.*sep.*')
# Out:
#      sepal length (cm)  sepal width (cm)
# 0                  5.1              -1.5
# 1                  4.9               3.0
# 2                  4.7               3.2
# 3                  4.6               3.1
# 4                  5.0               3.6
# ..                 ...               ...
# 145                6.7               3.0
# 146                6.3               2.5
# 147                6.5               3.0
# 148                6.2               3.4
# 149                5.9               3.0
#
# [150 rows x 2 columns]

# %%
df.groupby([df.columns[1]]).mean()[df.columns[0]]
# Out:
# sepal width (cm)
# -1.5    5.100000
#  2.0    5.000000
#  2.2    6.066667
#  2.3    5.325000
#  2.4    5.300000
#  2.5    5.762500
#  2.6    6.160000
#  2.7    5.855556
#  2.8    6.335714
#  2.9    6.060000
#  3.0    6.015385
#  3.1    6.036364
#  3.2    5.884615
#  3.3    6.016667
#  3.4    5.316667
#  3.5    5.160000
#  3.6    5.425000
#  3.7    5.266667
#  3.8    6.100000
#  3.9    5.400000
#  4.0    5.800000
#  4.1    5.200000
#  4.2    5.500000
#  4.4    5.700000
# Name: sepal length (cm), dtype: float64

# %%
df.hist();

# %%
df.filter?

# %%
#df.corr()
import seaborn as sns
sns.heatmap(df.corr(),annot=True);
